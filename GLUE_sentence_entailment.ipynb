# %%
# !pip3 install transformers
# !pip3 install datasets
# !pip3 install textaugment
# !pip3 install gensim==3.6.0
# Out:
# Requirement already satisfied: transformers in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (4.17.0)
# Requirement already satisfied: sacremoses in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from transformers) (0.0.47)
# Requirement already satisfied: importlib-metadata in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from transformers) (4.11.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from transformers) (3.6.0)
# Requirement already satisfied: numpy>=1.17 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from transformers) (1.21.5)
# Requirement already satisfied: regex!=2019.12.17 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from transformers) (2022.1.18)
# Requirement already satisfied: requests in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from transformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from transformers) (4.62.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from transformers) (0.4.0)
# Requirement already satisfied: packaging>=20.0 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from transformers) (21.3)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from transformers) (0.11.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from requests->transformers) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: click in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from sacremoses->transformers) (8.0.4)
# Requirement already satisfied: six in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: datasets in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (1.18.3)
# Requirement already satisfied: pandas in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from datasets) (1.3.5)
# Requirement already satisfied: aiohttp in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from datasets) (3.8.1)
# Requirement already satisfied: packaging in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from datasets) (21.3)
# Requirement already satisfied: numpy>=1.17 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from datasets) (1.21.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: dill in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from datasets) (0.3.4)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from datasets) (2022.1.0)
# Requirement already satisfied: tqdm>=4.62.1 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from datasets) (4.62.3)
# Requirement already satisfied: requests>=2.19.0 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from datasets) (2.27.1)
# Requirement already satisfied: importlib-metadata in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from datasets) (4.11.1)
# Requirement already satisfied: multiprocess in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: xxhash in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: filelock in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.7.4.3)
# Requirement already satisfied: pyyaml in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from packaging->datasets) (3.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from requests>=2.19.0->datasets) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from requests>=2.19.0->datasets) (1.26.8)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: zipp>=0.5 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from importlib-metadata->datasets) (3.7.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from pandas->datasets) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Requirement already satisfied: textaugment in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (1.3.4)
# Requirement already satisfied: nltk in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from textaugment) (3.7)
# Requirement already satisfied: numpy in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from textaugment) (1.21.5)
# Requirement already satisfied: textblob in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from textaugment) (0.17.1)
# Requirement already satisfied: googletrans in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from textaugment) (3.0.0)
# Requirement already satisfied: gensim in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from textaugment) (3.6.0)
# Requirement already satisfied: six>=1.5.0 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from gensim->textaugment) (1.15.0)
# Requirement already satisfied: smart-open>=1.2.1 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from gensim->textaugment) (5.2.1)
# Requirement already satisfied: scipy>=0.18.1 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from gensim->textaugment) (1.7.3)
# Requirement already satisfied: httpx==0.13.3 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from googletrans->textaugment) (0.13.3)
# Requirement already satisfied: hstspreload in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from httpx==0.13.3->googletrans->textaugment) (2021.12.1)
# Requirement already satisfied: httpcore==0.9.* in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from httpx==0.13.3->googletrans->textaugment) (0.9.1)
# Requirement already satisfied: idna==2.* in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from httpx==0.13.3->googletrans->textaugment) (2.10)
# Requirement already satisfied: chardet==3.* in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from httpx==0.13.3->googletrans->textaugment) (3.0.4)
# Requirement already satisfied: rfc3986<2,>=1.3 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from httpx==0.13.3->googletrans->textaugment) (1.5.0)
# Requirement already satisfied: sniffio in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from httpx==0.13.3->googletrans->textaugment) (1.2.0)
# Requirement already satisfied: certifi in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from httpx==0.13.3->googletrans->textaugment) (2021.10.8)
# Requirement already satisfied: h2==3.* in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans->textaugment) (3.2.0)
# Requirement already satisfied: h11<0.10,>=0.8 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans->textaugment) (0.9.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans->textaugment) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans->textaugment) (3.0.0)
# Requirement already satisfied: click in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from nltk->textaugment) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from nltk->textaugment) (2022.1.18)
# Requirement already satisfied: tqdm in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from nltk->textaugment) (4.62.3)
# Requirement already satisfied: joblib in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from nltk->textaugment) (1.1.0)
# Requirement already satisfied: importlib-metadata in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from click->nltk->textaugment) (4.11.1)
# Requirement already satisfied: zipp>=0.5 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from importlib-metadata->click->nltk->textaugment) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from importlib-metadata->click->nltk->textaugment) (3.7.4.3)
# Requirement already satisfied: gensim==3.6.0 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (3.6.0)
# Requirement already satisfied: smart-open>=1.2.1 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from gensim==3.6.0) (5.2.1)
# Requirement already satisfied: numpy>=1.11.3 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from gensim==3.6.0) (1.21.5)
# Requirement already satisfied: six>=1.5.0 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from gensim==3.6.0) (1.15.0)
# Requirement already satisfied: scipy>=0.18.1 in /home/projects/competitions/nlp/kaggle_feedback_prize_2021/kutuzov/kaggle_env/lib/python3.7/site-packages (from gensim==3.6.0) (1.7.3)

# %%
import nltk
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("omw-1.4")
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/kutuzov/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/kutuzov/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/kutuzov/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/kutuzov/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# Загрузим необходимый датасет и посмотрим, сколько в нем элементов и как в них сбалансированы классы

# %%
from datasets import load_dataset
from collections import Counter

rte_dataset = load_dataset("glue", "rte")

for data_type in rte_dataset.keys():
    counts = Counter(rte_dataset[data_type]['label'])
    print(f"{data_type}: {','.join([f'{key} - {value}' for key, value in counts.items()])}")
# Out:
# Reusing dataset glue (/home/kutuzov/.cache/huggingface/datasets/glue/rte/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
#   0%|          | 0/3 [00:00<?, ?it/s]
# train: 1 - 1241,0 - 1249
# validation: 1 - 131,0 - 146
# test: -1 - 3000

# %% [markdown]
# Посмотрим максимальную длину предложения в символах:

# %%
from typing import List, Dict
import random

import torch
from transformers import AutoModel, AutoTokenizer, AutoConfig, AutoModelForSequenceClassification
from torch import nn
from torch.utils.data import Dataset, DataLoader
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from torch.optim import Adam, AdamW
from torch.optim.lr_scheduler import ReduceLROnPlateau, MultiStepLR
from torch.nn import CrossEntropyLoss
from tqdm import tqdm
from datasets import concatenate_datasets, DatasetDict

device = "cuda:0" if torch.cuda.is_available() else "cpu"

# %%
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

# %% [markdown]
# Проведем аугментацию данных, чтобы увеличить их количество

# %%
from gensim import downloader
from textaugment.word2vec import Word2vec

def augment_dataset(augmenter):
    def augment(x):
        return {"sentence1": augmenter(x["sentence1"]),
                "sentence2": augmenter(x["sentence2"]),
                "label": x["label"]}
    
    return augment

def random_swap_augment(sentence):
    for i in range(3):
        sentence = swap_augmenter.random_swap(sentence)
    return sentence 
    

word2vec_model = downloader.load('fasttext-wiki-news-subwords-300')
word2vec_augmenter = Word2vec(model=word2vec_model, p=0.5)

augmented_train_data_w2v = rte_dataset["train"].map(augment_dataset(word2vec_augmenter.augment))
augmented_train_data_swaper = rte_dataset["train"].map(augment_dataset(random_swap_augment))
augmented_train_data = concatenate_datasets((augmented_train_data_w2v, augmented_train_data_swaper))

augmented_rte_dataset = DatasetDict()
augmented_rte_dataset["train"] = concatenate_datasets((rte_dataset["train"], augmented_train_data))
augmented_rte_dataset["validation"] = rte_dataset["validation"]
# Out:
# 0ex [00:00, ?ex/s]

# %%
class EntailmentDataset(Dataset):
    def __init__(self, data_container: Dataset):
        self.data = data_container
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        row_data = self.data[idx]
        
        sentence_1 = row_data["sentence1"]
        sentence_2 = row_data["sentence2"]
        sentences = sentence_1 + sentence_2
        y = row_data["label"]
        return sentences, y

n_classes = 2

# %%
def prepare_sentences_for_prediction(sentences, tokenizer):
    encoded_sentences = tokenizer(list(sentences), padding=True, truncation=True, return_tensors='pt')
    encoded_sentences = {key: value.to(device) for key, value in encoded_sentences.items()}
    return encoded_sentences

def train_fn(model, tokenizer, dataloader: DataLoader,
             loss_fn: callable, metrics: Dict[str, callable], optimizer):
    model.train()
    
    running_loss = 0
    running_losses = []
    metrics_values = {key: 0 for key in metrics}
    
    for x, y in dataloader:
        x = prepare_sentences_for_prediction(x, tokenizer)
        
        optimizer.zero_grad()
        
        output = model(**x).logits
        y_preds = output.argmax(axis=-1)
        
        loss = loss_fn(output, y.to(device))
        loss.backward()
        
        nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        
        running_losses.append(loss.item())
        running_loss += loss.item()
        
        for metric_name in metrics:
            if "precision" in metric_name or "recall" in metric_name:
                metrics_values[metric_name] += metrics[metric_name](y, y_preds.cpu(), zero_division=0)
            else:
                metrics_values[metric_name] += metrics[metric_name](y, y_preds.cpu())
            
    return running_loss / len(dataloader),{key: value / len(dataloader) for key, value in metrics_values.items()}

# %%
def calculate_weights(labels):
    counts = Counter(labels)
    
    weights = [0 for _ in range(len(counts))]
    
    for key, value in counts.items():
        weights[key] = 2 * len(labels) / value
        
    weights = torch.FloatTensor(weights)
    
    return weights


def eval_fn(model, tokenizer, dataloader: DataLoader,
             loss_fn: callable, metrics: Dict[str, callable]):
    model.eval()
    
    mean_prediction = 0
    running_loss = 0
    metrics_values = {key: 0 for key in metrics}
    
    for x, y in dataloader:
        x = prepare_sentences_for_prediction(x, tokenizer)
        
        with torch.no_grad():
            output = model(**x).logits
        y_preds = output.argmax(axis=-1)
        
        loss = loss_fn(output, y.to(device))
        running_loss += loss.item()
        
        for metric_name in metrics:
            if "precision" in metric_name or "recall" in metric_name:
                metrics_values[metric_name] += metrics[metric_name](y, y_preds.cpu(), zero_division=0)
            else:
                metrics_values[metric_name] += metrics[metric_name](y, y_preds.cpu())
        
        mean_prediction += y_preds.cpu().sum()
    return running_loss / len(dataloader),{key: value / len(dataloader) for key, value in metrics_values.items()}

def f1_score_wrapper(n_classes):
    if n_classes != 2:
        return lambda x, y: f1_score(x, y, average="micro")
    
    return f1_score

def check_hypothesis(model_name, dataset, epochs, batch_size=32,
                     weighted=False, metrics_for_logging=dict(),
                     lr=1e-2, n_classes=2):
    model_config = AutoConfig.from_pretrained(model_name, num_labels=n_classes)
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForSequenceClassification.from_pretrained(model_name, config=model_config,
                                                              ignore_mismatched_sizes=True)
    model = model.to(device)
    
    train_dataset = EntailmentDataset(dataset["train"])
    eval_dataset = EntailmentDataset(dataset["validation"])
    
    if weighted:
        weights = calculate_weights(dataset["train"]["label"])
    else:
        weights = torch.FloatTensor([1 for _ in range(n_classes)])
    
    train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    eval_dataloader = DataLoader(eval_dataset, batch_size=32, shuffle=True)
    
    train_losses, train_metrics, eval_losses, eval_metrics = [], [], [], []
    
    for key in metrics_for_logging.keys():
        if "f1" in key:
            metrics_for_logging[key] = f1_score_wrapper(n_classes)
            
    optimizer = AdamW(model.parameters(), lr=lr, weight_decay=1e-5)
    scheduler = MultiStepLR(optimizer, milestones=[2, 4, 6, 8], gamma=0.25)
    
    for epoch in tqdm(range(epochs)):
        train_loss, train_metric = train_fn(model, tokenizer, train_dataloader,
                                            CrossEntropyLoss(weights.to(device)), metrics_for_logging, optimizer)
        
        eval_loss, eval_metric = eval_fn(model, tokenizer,
                                         eval_dataloader, CrossEntropyLoss(weights.to(device)), 
                                         metrics_for_logging)
        scheduler.step()
        
        train_losses.append(train_loss)
        train_metrics.append(train_metric)
        
        eval_losses.append(eval_loss)
        eval_metrics.append(eval_metric)
    return model, train_losses, train_metrics, eval_losses, eval_metrics

# %%
logging_data = {x: [] for x in ("Model name", "Dataset", "Loss", "Lr",
                               "accuracy", "f1", "precision", "recall")}

for model_name in ["cardiffnlp/twitter-roberta-base-sentiment", "facebook/bart-base"]:
    for lr in [2e-5, 5e-5, 1e-4]:
        hypothesis_result = check_hypothesis(model_name, augmented_rte_dataset, 5, 32, True,
                                             {"accuracy": accuracy_score, "f1": f1_score,
                                              "precision":precision_score, "recall":recall_score},
                                             lr=lr)
        
        model, train_losses, train_metrics, eval_losses, eval_metrics = hypothesis_result
            
        logging_data["Model name"].append(model_name)
        logging_data["Dataset"].append("rte")
        logging_data["Loss"].append(min(eval_losses))
        logging_data["Lr"].append(lr)
            
        logging_data["accuracy"].append(max(map(lambda x: x["accuracy"], eval_metrics)))
            
        f1_maximum_index = np.argmax(list(map(lambda x: x["f1"], eval_metrics)))
        
        for key, value in eval_metrics[f1_maximum_index].items():
            if key != "accuracy":
                logging_data[key].append(value)
        
        for key, value in logging_data.items():
            print(f"{key}: {value[-1]}", end=", ")
            print()

# %%
import pandas as pd

df = pd.DataFrame(logging_data)
df

# %%
df.to_csv("logs_entailment.csv", index=False)
